# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
# Convert categorical data to numeric and separate target feature for training data
from sklearn.preprocessing import StandardScaler, LabelEncoder
X_train_dummies = pd.get_dummies(train_df.drop('loan_status', axis = 1))
X_train_dummies
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment  annual_inc  \
# 0           57107   57107    13375.0    0.1797       483.34    223000.0
# 1          141451  141451    21000.0    0.1308       478.68    123000.0
# 2          321143  321143    20000.0    0.1240       448.95    197000.0
# 3           11778   11778     3000.0    0.1240       100.22     45000.0
# 4          169382  169382    30000.0    0.1612      1056.49    133000.0
# ...           ...     ...        ...       ...          ...         ...
# 12175      354912  354912    19975.0    0.2565       801.09     28000.0
# 12176      354944  354944    15000.0    0.1774       540.34     50000.0
# 12177      354973  354973     3600.0    0.1862       131.28     60000.0
# 12178      355002  355002    15000.0    0.0881       475.68     62000.0
# 12179      355307  355307    15000.0    0.1774       540.34     54080.0
#
#          dti  delinq_2yrs  inq_last_6mths  open_acc  ...  \
# ...

# %%
X_train_dummies.loc[:, ~X_train_dummies.columns.str.match('Unnamed')]
# Out:
#         index  loan_amnt  int_rate  installment  annual_inc    dti  \
# 0       57107    13375.0    0.1797       483.34    223000.0  29.99
# 1      141451    21000.0    0.1308       478.68    123000.0  11.26
# 2      321143    20000.0    0.1240       448.95    197000.0  11.28
# 3       11778     3000.0    0.1240       100.22     45000.0  18.08
# 4      169382    30000.0    0.1612      1056.49    133000.0  27.77
# ...       ...        ...       ...          ...         ...    ...
# 12175  354912    19975.0    0.2565       801.09     28000.0  28.42
# 12176  354944    15000.0    0.1774       540.34     50000.0  23.43
# 12177  354973     3600.0    0.1862       131.28     60000.0  28.80
# 12178  355002    15000.0    0.0881       475.68     62000.0  11.44
# 12179  355307    15000.0    0.1774       540.34     54080.0  21.66
#
#        delinq_2yrs  inq_last_6mths  open_acc  pub_rec  ...  \
# 0              0.0             0.0      15.0      0.0  ...
# ...

# %%
del X_train_dummies['index']

# %%
X_train_dummies
# Out:
#        Unnamed: 0  loan_amnt  int_rate  installment  annual_inc    dti  \
# 0           57107    13375.0    0.1797       483.34    223000.0  29.99
# 1          141451    21000.0    0.1308       478.68    123000.0  11.26
# 2          321143    20000.0    0.1240       448.95    197000.0  11.28
# 3           11778     3000.0    0.1240       100.22     45000.0  18.08
# 4          169382    30000.0    0.1612      1056.49    133000.0  27.77
# ...           ...        ...       ...          ...         ...    ...
# 12175      354912    19975.0    0.2565       801.09     28000.0  28.42
# 12176      354944    15000.0    0.1774       540.34     50000.0  23.43
# 12177      354973     3600.0    0.1862       131.28     60000.0  28.80
# 12178      355002    15000.0    0.0881       475.68     62000.0  11.44
# 12179      355307    15000.0    0.1774       540.34     54080.0  21.66
#
#        delinq_2yrs  inq_last_6mths  open_acc  pub_rec  ...  \
# ...

# %%
X_train_dummies= X_train_dummies.loc[:, ~X_train_dummies.columns.str.match('Unnamed')]

# %%
X_train_dummies
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0        13375.0    0.1797       483.34    223000.0  29.99          0.0
# 1        21000.0    0.1308       478.68    123000.0  11.26          2.0
# 2        20000.0    0.1240       448.95    197000.0  11.28          0.0
# 3         3000.0    0.1240       100.22     45000.0  18.08          0.0
# 4        30000.0    0.1612      1056.49    133000.0  27.77          0.0
# ...          ...       ...          ...         ...    ...          ...
# 12175    19975.0    0.2565       801.09     28000.0  28.42          0.0
# 12176    15000.0    0.1774       540.34     50000.0  23.43          4.0
# 12177     3600.0    0.1862       131.28     60000.0  28.80          0.0
# 12178    15000.0    0.0881       475.68     62000.0  11.44          0.0
# 12179    15000.0    0.1774       540.34     54080.0  21.66          1.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# ...

# %%
# Convert categorical data to numeric and separate target feature for testing data
X_test_dummies = pd.get_dummies(test_df.drop('loan_status', axis = 1))
# test_df['loan_status'] =  LabelEncoder().fit_transform(test_df['loan_status'])
# test_df['home_ownership'] =  LabelEncoder().fit_transform(test_df['home_ownership'])
# test_df['verification_status'] =  LabelEncoder().fit_transform(test_df['verification_status'])
# test_df['hardship_flag'] =  LabelEncoder().fit_transform(test_df['hardship_flag'])
# test_df['debt_settlement_flag'] =  LabelEncoder().fit_transform(test_df['debt_settlement_flag'])

# test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70               1
# 1       25429  25429     6000.0    0.1524       208.70               3
# 2       38496  38496     3600.0    0.1695       128.27               3
# 3       19667  19667    20000.0    0.1524       478.33               3
# 4       37505  37505     3600.0    0.1240       120.27               3
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    140000.0                    0            1          n  ...
# 1     55000.0                    0            1          n  ...
# 2     42000.0                    0            1          n  ...
# 3    100000.0                    0            1          n  ...
# 4     50000.0                    0            1          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            97.7               0.0                   0.0        0.0
# ...

# %%
# add missing dummy variables to testing set

# %%
# Train the Logistic Regression model on the unscaled data and print the model score

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
